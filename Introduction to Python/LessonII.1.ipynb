# %% [markdown]
# < [Contents](_Intro.ipynb) | [Lesson I: What is Python?](LessonI.ipynb) | [Lesson II.2. String Data Type](LessonII.2.ipynb) >
#
# #### **1. Variables and Assignment**
#
# - variable is a string of characters to store information. They may contain alphanumeric characters, underscores, and are case sensitive.
# - assignment operator `=` is used to assign information

# %%
x = 0.5
x
# Out:
# 0.5

# %%
y = 0.2
y
# Out:
# 0.2

# %% [markdown]
# - IPython kernel require `%` fo specify commands.
# - `%whos` lists all the variables.

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# x          float    0.5
# y          float    0.2

# %% [markdown]
# - writing `?` after the variable, prints the information about the variable

# %%
x?
# Out:
# Type:        float
# String form: 0.5
# Docstring:   Convert a string or number to a floating-point number, if possible.

# %% [markdown]
# - `dir()` is used to print all the properties or attritbutes of object

# %%
dir(x)
