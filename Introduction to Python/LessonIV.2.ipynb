# %% [markdown]
# < [Contents](_Intro.ipynb) | [Lesson IV.1. NumPy](LessonIII.7.ipynb) | [Lesson IV.1. NumPy](LessonIV.1.ipynb) >
# #### **2. Matplotlib**
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations.
#
# See the following link to Matplotlib documentation: [Matplotlib User Guide](https://matplotlib.org/stable/users/index.html)
