# %% [markdown]
# < [Contents](_Intro.ipynb) | [Lesson IV.2. Matplotlib](LessonIV.2..ipynb) | >
# #### **3. OpenCV **
#
# OpenCV is the biggest computer vision library.
#
# See the following link to [OpenCV Python Tutorials](https://docs.opencv.org/4.10.0/d6/d00/tutorial_py_root.html)
